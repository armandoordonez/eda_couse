# %% [markdown]
# <a href="https://colab.research.google.com/github/RaulEcheverryLopez/eda_couse-Analisis-Expliratorio1/blob/RaulEcheverryLopez/Pipeline_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Taller Analisis Exploratorio 1
# Importamos las librerías

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# Estilos

# %%
df = pd.read_csv("basepilenes.csv")
df.head()
# Out:
#    Unnamed: 0   ID  BT Sucursal  Antigüedad    Sexo Sector Actividad  \
# 0           0  1.0         80.0         2.0   Mujer         COMERCIO
# 1           4  2.0          2.0         2.0   Mujer      AGRICULTURA
# 2           7  3.0         74.0         2.0   Mujer         COMERCIO
# 3          10  4.0         74.0         2.0  Hombre       ARTESANÍAS
# 4          14  5.0         57.0         2.0   Mujer        SERVICIOS
#
#    Plazo Meses             Destino  Edad  Personas a Cargo  Antigüedad Mes  \
# 0         12.0         Activo fijo  24.0               0.0             1.0
# 1         23.0  Capital de trabajo  34.0               1.0            12.0
# 2         20.0  Capital de trabajo  23.0               0.0             5.0
# 3         16.0  Capital de trabajo  22.0               0.0            13.0
# 4         14.0  Capital de trabajo  21.0               0.0             0.0
#
#    Días Vencido  Mora
# 0           0.0     0
# 1         137.0     1
# 2           0.0     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129569 entries, 0 to 129568
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        129569 non-null  int64
#  1   ID                129569 non-null  float64
#  2   BT Sucursal       129569 non-null  float64
#  3   Antigüedad        129569 non-null  float64
#  4   Sexo              129569 non-null  object
#  5   Sector Actividad  129569 non-null  object
#  6   Plazo Meses       129569 non-null  float64
#  7   Destino           129569 non-null  object
#  8   Edad              129569 non-null  float64
#  9   Personas a Cargo  129569 non-null  float64
#  10  Antigüedad Mes    129569 non-null  float64
#  11  Días Vencido      129569 non-null  float64
#  12  Mora              129569 non-null  int64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 12.9+ MB

# %%
# Creamos un nuevo dataset en donde seleccionamos las columnas que usaremos para el analisis
df_base=df_sin_dup[["ID","BT Sucursal","Antigüedad","Sexo","Sector Actividad","Plazo Meses","Destino","Edad","Días Vencido"]]
df_base.head()
# Out:
#     ID  BT Sucursal  Antigüedad    Sexo Sector Actividad  Plazo Meses  \
# 0  1.0         80.0         2.0   Mujer         COMERCIO         12.0
# 1  2.0          2.0         2.0   Mujer      AGRICULTURA         23.0
# 2  3.0         74.0         2.0   Mujer         COMERCIO         20.0
# 3  4.0         74.0         2.0  Hombre       ARTESANÍAS         16.0
# 4  5.0         57.0         2.0   Mujer        SERVICIOS         14.0
#
#               Destino  Edad  Días Vencido
# 0         Activo fijo  24.0           0.0
# 1  Capital de trabajo  34.0         137.0
# 2  Capital de trabajo  23.0           0.0
# 3  Capital de trabajo  22.0           0.0
# 4  Capital de trabajo  21.0           0.0

# %%
#informacion de la Base sin duplicados
df_sin_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129569 entries, 0 to 129568
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        129569 non-null  int64
#  1   ID                129569 non-null  float64
#  2   BT Sucursal       129569 non-null  float64
#  3   Antigüedad        129569 non-null  float64
#  4   Sexo              129569 non-null  object
#  5   Sector Actividad  129569 non-null  object
#  6   Plazo Meses       129569 non-null  float64
#  7   Destino           129569 non-null  object
#  8   Edad              129569 non-null  float64
#  9   Personas a Cargo  129569 non-null  float64
#  10  Antigüedad Mes    129569 non-null  float64
#  11  Días Vencido      129569 non-null  float64
#  12  Mora              129569 non-null  int64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 13.8+ MB

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier

# scoring data
from sklearn.metrics import accuracy_score

# dataset is imported from inbuilt sklearn datasets
iris = datasets.load_iris()
X = iris.data
y = iris.target

#The data spliting is executed here
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.50)

# importing pipes for making the Pipe flow
from sklearn.pipeline import Pipeline
# The sequence of pipe flow is :
# Data gets scaled >> Classification of decission tree
pipe = Pipeline([('pca', PCA(n_components = 2)),('std', StandardScaler()), ('decision_tree', DecisionTreeClassifier())], verbose = True)

# fitting the data in the pipeline
pipe.fit(X_train, y_train)


print(accuracy_score(y_test, pipe.predict(X_test)))
# Out:
# [Pipeline] ............... (step 1 of 3) Processing pca, total=   0.0s
# [Pipeline] ............... (step 2 of 3) Processing std, total=   0.0s
# [Pipeline] ..... (step 3 of 3) Processing decision_tree, total=   0.0s
# 0.96

# %%
pipe = Pipeline([('pca', PCA(n_components = 2)), ('decision_tree', DecisionTreeClassifier())], verbose = True)

# fitting the data in the pipeline
pipe.fit(X_train, y_train)

# scoring data
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pipe.predict(X_test)))
# Out:
# [Pipeline] ............... (step 1 of 2) Processing pca, total=   0.0s
# [Pipeline] ..... (step 2 of 2) Processing decision_tree, total=   0.0s
# 0.96

# %%
pipe = Pipeline([('decision_tree', DecisionTreeClassifier())], verbose = True)

# fitting the data in the pipeline
pipe.fit(X_train, y_train)

# scoring data
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pipe.predict(X_test)))
# Out:
# [Pipeline] ..... (step 1 of 1) Processing decision_tree, total=   0.0s
# 0.9733333333333334
