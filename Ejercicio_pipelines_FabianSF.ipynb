# %% [markdown]
# # Síndrome del ovario poliquístico (SOPQ)

# %%
import pandas as pd

# Ruta al archivo CSV (ajústala según tu ubicación)
ruta_archivo = "alfa7g7/eda_couse/data/PCOS_data.csv"

# Carga los datos desde el archivo CSV
df = pd.read_csv(ruta_archivo)

# Muestra las primeras filas del DataFrame
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 ruta_archivo = "alfa7g7/eda_couse/data/PCOS_data.csv"
#       6 # Carga los datos desde el archivo CSV
# ----> 7 df = pd.read_csv(ruta_archivo)
#       9 # Muestra las primeras filas del DataFrame
#      10 print(df.head())
#
# ...
